# %%
import pandas as pd
from pathlib import Path
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('video_games.csv')

# %%
file = Path('video_games.csv')

# %%
df = pd.read_csv(file, encoding="ISO-8859-1")

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %%
df.columns
game_sales_df = df[['Name', 'NA_Sales', 'EU_Sales', 'Other_Sales', 'Global_Sales']]
game_sales_df
# Out:
#                                 Name  NA_Sales  EU_Sales  Other_Sales  \
# 0                         Wii Sports     41.36     28.96         8.45
# 1                  Super Mario Bros.     29.08      3.58         0.77
# 2                     Mario Kart Wii     15.68     12.76         3.29
# 3                  Wii Sports Resort     15.61     10.93         2.95
# 4           Pokemon Red/Pokemon Blue     11.27      8.89         1.00
# ...                              ...       ...       ...          ...
# 16714  Samurai Warriors: Sanada Maru      0.00      0.00         0.00
# 16715               LMA Manager 2007      0.00      0.01         0.00
# 16716        Haitaka no Psychedelica      0.00      0.00         0.00
# 16717               Spirits & Spells      0.01      0.00         0.00
# 16718            Winning Post 8 2016      0.00      0.00         0.00
#
#        Global_Sales
# 0             82.53
# 1             40.24
# 2             35.52
# 3             32.77
# 4             31.37
# ...             ...
# 16714          0.01
# 16715          0.01
# 16716          0.01
# 16717          0.01
# 16718          0.01
#
# [16719 rows x 5 columns]

# %%
#Highest Selling game of all tim
highest_sales_row = df.nlargest(1, 'Global_Sales')
highest_selling_game = highest_sales_row['Name'].iloc[0]
print("The highest selling game of all time is:", highest_selling_game)
# Out:
# The highest selling game of all time is: Wii Sports

# %%
#Lowest Selling game of all time
lowest_sales_row = df.nsmallest(1, 'Global_Sales')
lowest_selling_game = lowest_sales_row['Name'].iloc[0]
print("The lowest selling game of all time is:", lowest_selling_game)
# Out:
# The lowest selling game of all time is: Football Manager 2007

# %%
game_sales_df = df[['Name', 'Global_Sales', 'Platform']]
game_sales_df
# Out:
#                                 Name  Global_Sales Platform
# 0                         Wii Sports         82.53      Wii
# 1                  Super Mario Bros.         40.24      NES
# 2                     Mario Kart Wii         35.52      Wii
# 3                  Wii Sports Resort         32.77      Wii
# 4           Pokemon Red/Pokemon Blue         31.37       GB
# ...                              ...           ...      ...
# 16714  Samurai Warriors: Sanada Maru          0.01      PS3
# 16715               LMA Manager 2007          0.01     X360
# 16716        Haitaka no Psychedelica          0.01      PSV
# 16717               Spirits & Spells          0.01      GBA
# 16718            Winning Post 8 2016          0.01      PSV
#
# [16719 rows x 3 columns]

# %%
#50 HIGHEST selling games of all time
game_sales_df = df[['Name', 'Global_Sales', 'Platform']]
game_sales_df
top_50 = game_sales_df.sort_values('Global_Sales', ascending=False).head(50)

print(top_50)
# Out:
#                                             Name  Global_Sales Platform
# 0                                     Wii Sports         82.53      Wii
# 1                              Super Mario Bros.         40.24      NES
# 2                                 Mario Kart Wii         35.52      Wii
# 3                              Wii Sports Resort         32.77      Wii
# 4                       Pokemon Red/Pokemon Blue         31.37       GB
# 5                                         Tetris         30.26       GB
# 6                          New Super Mario Bros.         29.80       DS
# 7                                       Wii Play         28.92      Wii
# 8                      New Super Mario Bros. Wii         28.32      Wii
# 9                                      Duck Hunt         28.31      NES
# 10                                    Nintendogs         24.67       DS
# 11                                 Mario Kart DS         23.21       DS
# 12                   Pokemon Gold/Pokemon Silver         23.10       GB
# 13                                       Wii Fit         22.70      Wii
# 14                            Kinect Adventures!         21.81     X360
# 15                                  Wii Fit Plus         21.79      Wii
# 16                            Grand Theft Auto V         21.04      PS3
# 17                 Grand Theft Auto: San Andreas         20.81      PS2
# 18                             Super Mario World         20.61     SNES
# 19  Brain Age: Train Your Brain in Minutes a Day         20.15       DS
# 20                 Pokemon Diamond/Pokemon Pearl         18.25       DS
# 21                              Super Mario Land         18.14       GB
# 22                           Super Mario Bros. 3         17.28      NES
# 23                            Grand Theft Auto V         16.27     X360
# 24                   Grand Theft Auto: Vice City         16.15      PS2
# 25                 Pokemon Ruby/Pokemon Sapphire         15.85      GBA
# 26   Brain Age 2: More Training in Minutes a Day         15.29       DS
# 27                   Pokemon Black/Pokemon White         15.14       DS
# 28                        Gran Turismo 3: A-Spec         14.98      PS2
# 29                Call of Duty: Modern Warfare 3         14.73     X360
# 30      Pok̩mon Yellow: Special Pikachu Edition         14.64       GB
# 31                     Call of Duty: Black Ops 3         14.63      PS4
# 32                       Call of Duty: Black Ops         14.61     X360
# 33                           Pokemon X/Pokemon Y         14.60      3DS
# 34                    Call of Duty: Black Ops II         13.79      PS3
# 35                    Call of Duty: Black Ops II         13.67     X360
# 36                Call of Duty: Modern Warfare 2         13.47     X360
# 37                Call of Duty: Modern Warfare 3         13.32      PS3
# 38                          Grand Theft Auto III         13.10      PS2
# 39                       Super Smash Bros. Brawl         12.84      Wii
# 40                                  Mario Kart 7         12.66      3DS
# 41                       Call of Duty: Black Ops         12.63      PS3
# 42                            Grand Theft Auto V         12.61      PS4
# 43                   Animal Crossing: Wild World         12.13       DS
# 44                                        Halo 3         12.12     X360
# 45                                Super Mario 64         11.89      N64
# 46          Pokemon HeartGold/Pokemon SoulSilver         11.77       DS
# 47     Pokemon Omega Ruby/Pokemon Alpha Sapphire         11.68      3DS
# 48                                Gran Turismo 4         11.66      PS2
# 49                            Super Mario Galaxy         11.35      Wii

# %%
plt.bar(top_50['Platform'], top_50['Global_Sales'])
plt.xticks(rotation=90)
plt.xlabel('Platform')
plt.ylabel('Global Sales (millions)')
plt.title('Top 50 Highest Selling Games of All Time')

plt.tight_layout()
plt.show()

# %%
#Create Bar graph for 50 HIGHEST selling games of all time

plt.bar(top_50['Name'], top_50['Global_Sales'])
plt.xticks(rotation=90)
plt.xlabel('Name')
plt.ylabel('Global Sales (millions)')
plt.title('Top 50 Highest Selling Games of All Time')
plt.show()

# %%
#50 LOWEST selling games of all time
game_sales_df = df[['Name', 'Global_Sales']]
game_sales_df
bottom_50 = game_sales_df.sort_values('Global_Sales', ascending=True).head(50)

print(bottom_50)
# Out:
#                                                     Name  Global_Sales
# 16718                                Winning Post 8 2016          0.01
# 16296             AKB1/48: Idol to Guam de Koishitara...          0.01
# 16295                                             Casper          0.01
# 16294  Simple 2000 Series Vol. 120: The Saigo no Nipp...          0.01
# 16293                 Rave Master: Special Attack Force!          0.01
# 16292                                     K-1 Grand Prix          0.01
# 16291                                             Shorts          0.01
# 16290                               Metal Slug Anthology          0.01
# 16297        Adventure Time: The Secret of the Nameless           0.01
# 16289                                        Truck Racer          0.01
# 16287             Tantei Jinguuji Saburo: Hai to Diamond          0.01
# 16286                                   Toro to Morimori          0.01
# 16285    Fatal Fury: Battle Archives Volume 2 (JP sales)          0.01
# 16284                        Sakura-Sou no Pet na Kanojo          0.01
# 16283              Sherlock Holmes: The Devil's Daughter          0.01
# 16282                  Brain Exercise With Dr. Kawashima          0.01
# 16281                                    Princess Arthur          0.01
# 16288                                       Satisfashion          0.01
# 16280                    Homeworld Remastered Collection          0.01
# 16298                              Football Manager 2005          0.01
# 16300                                        BattleForge          0.01
# 16316                                     Bakumatsu Rock          0.01
# 16315                  Monster High: New Ghoul in School          0.01
# 16314                                      Banjo-Kazooie          0.01
# 16313                                     Rail Simulator          0.01
# 16312                                    Aa Megami-samaa          0.01
# 16311                                    Groovin' Blocks          0.01
# 16310                 Bunmei Kaika: Aoiza Ibunroku Saien          0.01
# 16299                             Hakuoki: Reimeiroku DS          0.01
# 16309     Tomoyo After: It's a Wonderful Life CS Edition          0.01
# 16307                                         Freekstyle          0.01
# 16306  Super Robot Monkey Team: Game Boy Advance Vide...          0.01
# 16305       Duel Love: Koisuru Otome wa Shouri no Megami          0.01
# 16304                                          Caladrius          0.01
# 16303                Barbie and Her Sisters Puppy Rescue          0.01
# 16302                         Ro-Kyu-Bu! Secret Photo Op          0.01
# 16301                                       Turbo Trainz          0.01
# 16308              Mystery Legends: Beauty and the Beast          0.01
# 16317                        Prototype: Biohazard Bundle          0.01
# 16279      Sangoku Koi Senki: Omoide Gaeshi - CS Edition          0.01
# 16277        Sega Golf Club: Miyazato San Kyoudai Naizou          0.01
# 16256                            Bratz: Forever Diamondz          0.01
# 16255                 Entaku no Seito: Students of Round          0.01
# 16254                                            Izumo 2          0.01
# 16253                                     Theatre Of War          0.01
# 16252                     SoulCalibur Legends (JP sales)          0.01
# 16251                Azure Striker Gunvolt: Striker Pack          0.01
# 16250                     Accel World: Kasoku no Chouten          0.01
# 16257                     Smiley World: Island Challenge          0.01
# 16249                                   Minna no Conveni          0.01

# %%
plt.bar(range(len(bottom_50['Name'])), bottom_50['Global_Sales'])
plt.xticks(range(len(bottom_50['Name'])), bottom_50['Name'], rotation=90)
plt.xlabel('Game')
plt.ylabel('Global Sales (hundreds)')
plt.title('Top 50 Lowest Selling Games of All Time')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\icamp\AppData\Local\Temp\ipykernel_9740\902563240.py:6: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
plt.bar(bottom_50['Name'], bottom_50['Global_Sales'])
plt.xticks(rotation=90)
plt.xlabel('Game')
plt.ylabel('Global Sales (hundreds)')
plt.title('Top 50 Lowest Selling Games of All Time')
plt.tight_layout()  # Optional, adjusts spacing between elements
plt.show()
# Out:
# C:\Users\icamp\AppData\Local\Temp\ipykernel_11872\4191785923.py:6: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()  # Optional, adjusts spacing between elements

# %%
plt.figure(figsize=(10, 6))  # Set width=10 inches, height=6 inches
plt.bar(range(len(bottom_50['Name'])), bottom_50['Global_Sales'])
plt.xticks(range(len(bottom_50['Name'])), bottom_50['Name'], rotation=90)
plt.xlabel('Game')
plt.ylabel('Global Sales (hundreds)')
plt.title('Top 50 Lowest Selling Games of All Time')
plt.tight_layout()
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv('video_games.csv')
#       2 publisher_sales = df.groupby('Publisher')['Global_Sales'].sum()
#       4 top_publishers = publisher_sales.sort_values(ascending=False).head(10)
#
# NameError: name 'pd' is not defined

# %%
df = pd.read_csv('video_games.csv')

publisher_releases = df['Publisher'].value_counts()

print(publisher_releases)
# Out:
# Electronic Arts                 1356
# Activision                       985
# Namco Bandai Games               939
# Ubisoft                          933
# Konami Digital Entertainment     834
#                                 ...
# Valve                              1
# ITT Family Games                   1
# Elite                              1
# Evolution Games                    1
# Red Flagship                       1
# Name: Publisher, Length: 581, dtype: int64

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv('video_games.csv')

# Count the number of releases for each publisher
publisher_releases = df['Publisher'].value_counts()

# Get the top 5 publishers
top_publishers = publisher_releases.head(5)

# Create a bar chart of the top 5 publishers
plt.bar(top_publishers.index, top_publishers.values)
plt.xlabel('Publisher')
plt.ylabel('Number of Releases')
plt.title('Top 5 Publishers by Number of Releases')
plt.xticks(rotation = 30, ha = 'right')

plt.show()

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv('video_games.csv')

# Count the number of releases for each publisher
publisher_releases = df['Publisher'].value_counts()

# Get the top 5 publishers
top_publishers = publisher_releases.head(5)

# Create a smaller figure
plt.figure(figsize=(8, 6))  # Adjust the width and height as needed

# Create a bar chart of the top 5 publishers
plt.bar(top_publishers.index, top_publishers.values)
plt.xlabel('Publisher', fontsize=12)  # Adjust the font size as needed
plt.ylabel('Number of Releases', fontsize=12)  # Adjust the font size as needed
plt.title('Top 5 Publishers by Number of Releases', fontsize=14)  # Adjust the font size as needed

# Abbreviate the publisher names
abbreviated_names = ['Pub1', 'Pub2', 'Pub3', 'Pub4', 'Pub5']
plt.xticks(range(len(top_publishers)), abbreviated_names, fontsize=10)  # Adjust the font size as needed

plt.tight_layout()  # Optional, adjusts spacing between elements

plt.show()

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv('video_games.csv')

# Define the list of publishers
publishers = ['Electronic Arts', 'Namco Bandai Games', 'Ubisoft', 'Konami Digital Entertainment']

# Filter the DataFrame for the specified publishers
filtered_df = df[df['Publisher'].isin(publishers)]

# Group the data by publisher and find the game with the maximum global sales
highest_selling_games = filtered_df.groupby('Publisher')['Global_Sales'].idxmax()
highest_selling_games = filtered_df.loc[highest_selling_games, ['Publisher', 'Name', 'Global_Sales']]

print(highest_selling_games)
# Out:
#                         Publisher                                 Name  \
# 77                Electronic Arts                              FIFA 16
# 144  Konami Digital Entertainment  Metal Gear Solid 2: Sons of Liberty
# 266            Namco Bandai Games                         Namco Museum
# 61                        Ubisoft                         Just Dance 3
#
#      Global_Sales
# 77           8.57
# 144          6.05
# 266          4.24
# 61          10.12

# %%
df = pd.read_csv('video_games.csv')

# Count the number of releases for each publisher
publisher_releases = df['Publisher'].value_counts()

# Get the top 5 publishers
top_publishers = publisher_releases.head(5)

# Create an empty dictionary to store the number one selling game for each publisher
top_games = {}

# Iterate over the top publishers
for publisher in top_publishers.index:
    # Filter the DataFrame for the current publisher
    publisher_df = df[df['Publisher'] == publisher]
    
    # Find the number one selling game for the current publisher
    top_game = publisher_df.loc[publisher_df['Global_Sales'].idxmax(), 'Name']
    
    # Store the number one selling game in the dictionary
    top_games[publisher] = top_game

# Print the top publishers and their number one selling games
for publisher, game in top_games.items():
    print(f"Publisher: {publisher}\tNumber One Selling Game: {game}")
# Out:
# Publisher: Electronic Arts	Number One Selling Game: FIFA 16
# Publisher: Activision	Number One Selling Game: Call of Duty: Modern Warfare 3
# Publisher: Namco Bandai Games	Number One Selling Game: Namco Museum
# Publisher: Ubisoft	Number One Selling Game: Just Dance 3
# Publisher: Konami Digital Entertainment	Number One Selling Game: Metal Gear Solid 2: Sons of Liberty
